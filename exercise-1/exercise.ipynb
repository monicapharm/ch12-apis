# %% [markdown]
# # Exercise 1
# Add the specified code for each code cell, running the cells _in order_.

# %% [markdown]
# In this exercise, you'll be accessing data from the [Github API](https://developer.github.com/v3/). You will need to read the documentation at **<https://developer.github.com/v3/>** in order to discover appropriate endpoints, their parameters, and their schemas. (Categories of endpoints are listed on the right, with multiple endpoints described per page).

# %% [markdown]
# First, import the **`requests`** module for accessing web data.

# %%
import requests

# %% [markdown]
# Create a variable **`base_uri`** that stores the base URI (as a string) for the Github API (`https://api.github.com`)

# %%
base_uri = "https://api.github.com"

# %% [markdown]
# Under the "Repositories" category of the API documentation, find the endpoint that will list _repos in an organization._ Then create a variable **`org_resource`** that stores the endpoint for the `infx511` organization repos (this is the _path_ to the resource of interest).
# - (FYI: this is where we keep the book code and master exercise sets!)

# %%
org_resource = "/orgs/infx511/repos"

# %% [markdown]
# Send a `get()` request to this endpoint (the `base_uri` followed by the `org_resource` path). Print the response's `status_code` and `url` to show that your request worked worked. (This will also allow you to inspect the JSON in the browser easily).

# %%
response = requests.get(base_uri + org_resource)
print(response.status_code)
print(response.url)
# Out:
# 200
# https://api.github.com/orgs/infx511/repos

# %% [markdown]
# Access the response's JSON content as a Python _list_. How many repositories does the organization have? (e.g., how many items are in the list?)

# %%
import json
content = response.json()
len(content)
# Out:
# 14

# %%
names = [repo['name'] for repo in content] # mapping
names
# Out:
# ['infx511.github.io',
#  'book',
#  'remote_practice',
#  'ch2-command-line',
#  'ch3-git-basics',
#  'ch4-python-intro',
#  'ch5-functions',
#  'ch6-logic',
#  'ch7-iteration',
#  'ch8-lists',
#  'ch9-dictionaries',
#  'ch10-searching',
#  'ch11-functional-programming',
#  'ch12-apis']

# %% [markdown]
# Create a variable **`search_endpoint`** that stores the endpoint used to search for repositories.

# %%
search_endpoint = "/search/repositories"

# %% [markdown]
# Use the `search_endpoint` to search for repositories about _"visualization"_. Access the response's JSON content, saving that data in a variable (e.g., `vis_repos`).

# %%
query_params = {'q':'visualization'}
response = requests.get(base_uri + search_endpoint, params = query_params)
response.text
vis_repos = response.json()

# %% [markdown]
# Print how many repositories your search returned. (Hint: yuo can first check the dictionary keys for the information you want).

# %%
vis_repos.keys()
len(vis_repos['items'])
vis_repos['items']
# Out:
# [{'archive_url': 'https://api.github.com/repos/d3/d3/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/d3/d3/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/d3/d3/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/d3/d3/branches{/branch}',
#   'clone_url': 'https://github.com/d3/d3.git',
#   'collaborators_url': 'https://api.github.com/repos/d3/d3/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/d3/d3/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/d3/d3/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/d3/d3/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/d3/d3/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/d3/d3/contributors',
#   'created_at': '2010-09-27T17:22:42Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/d3/d3/deployments',
#   'description': 'Bring data to life with SVG, Canvas and HTML. :bar_chart::chart_with_upwards_trend::tada:',
#   'downloads_url': 'https://api.github.com/repos/d3/d3/downloads',
#   'events_url': 'https://api.github.com/repos/d3/d3/events',
#   'fork': False,
#   'forks': 19212,
#   'forks_count': 19212,
#   'forks_url': 'https://api.github.com/repos/d3/d3/forks',
#   'full_name': 'd3/d3',
#   'git_commits_url': 'https://api.github.com/repos/d3/d3/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/d3/d3/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/d3/d3/git/tags{/sha}',
#   'git_url': 'git://github.com/d3/d3.git',
#   'has_downloads': True,
#   'has_issues': False,
#   'has_pages': False,
#   'has_projects': False,
#   'has_wiki': True,
#   'homepage': 'https://d3js.org',
#   'hooks_url': 'https://api.github.com/repos/d3/d3/hooks',
#   'html_url': 'https://github.com/d3/d3',
#   'id': 943149,
#   'issue_comment_url': 'https://api.github.com/repos/d3/d3/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/d3/d3/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/d3/d3/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/d3/d3/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/d3/d3/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/d3/d3/languages',
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause'},
#   'merges_url': 'https://api.github.com/repos/d3/d3/merges',
#   'milestones_url': 'https://api.github.com/repos/d3/d3/milestones{/number}',
#   'mirror_url': None,
#   'name': 'd3',
#   'notifications_url': 'https://api.github.com/repos/d3/d3/notifications{?since,all,participating}',
#   'open_issues': 4,
#   'open_issues_count': 4,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/1562726?v=4',
#    'events_url': 'https://api.github.com/users/d3/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/d3/followers',
#    'following_url': 'https://api.github.com/users/d3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/d3/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/d3',
#    'id': 1562726,
#    'login': 'd3',
#    'organizations_url': 'https://api.github.com/users/d3/orgs',
#    'received_events_url': 'https://api.github.com/users/d3/received_events',
#    'repos_url': 'https://api.github.com/users/d3/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/d3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/d3/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/d3'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/d3/d3/pulls{/number}',
#   'pushed_at': '2018-05-03T13:18:58Z',
#   'releases_url': 'https://api.github.com/repos/d3/d3/releases{/id}',
#   'score': 119.0426,
#   'size': 35952,
#   'ssh_url': 'git@github.com:d3/d3.git',
#   'stargazers_count': 75418,
#   'stargazers_url': 'https://api.github.com/repos/d3/d3/stargazers',
#   'statuses_url': 'https://api.github.com/repos/d3/d3/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/d3/d3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/d3/d3/subscription',
#   'svn_url': 'https://github.com/d3/d3',
#   'tags_url': 'https://api.github.com/repos/d3/d3/tags',
#   'teams_url': 'https://api.github.com/repos/d3/d3/teams',
#   'trees_url': 'https://api.github.com/repos/d3/d3/git/trees{/sha}',
#   'updated_at': '2018-05-03T23:06:54Z',
#   'url': 'https://api.github.com/repos/d3/d3',
#   'watchers': 75418,
#   'watchers_count': 75418},
#  {'archive_url': 'https://api.github.com/repos/hpcc-systems/Visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/hpcc-systems/Visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/hpcc-systems/Visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/hpcc-systems/Visualization/branches{/branch}',
#   'clone_url': 'https://github.com/hpcc-systems/Visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/hpcc-systems/Visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/hpcc-systems/Visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/hpcc-systems/Visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/hpcc-systems/Visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/hpcc-systems/Visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/hpcc-systems/Visualization/contributors',
#   'created_at': '2014-07-22T19:13:04Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/hpcc-systems/Visualization/deployments',
#   'description': 'HPCC Visualization Framework',
#   'downloads_url': 'https://api.github.com/repos/hpcc-systems/Visualization/downloads',
#   'events_url': 'https://api.github.com/repos/hpcc-systems/Visualization/events',
#   'fork': False,
#   'forks': 49,
#   'forks_count': 49,
#   'forks_url': 'https://api.github.com/repos/hpcc-systems/Visualization/forks',
#   'full_name': 'hpcc-systems/Visualization',
#   'git_commits_url': 'https://api.github.com/repos/hpcc-systems/Visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/hpcc-systems/Visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/hpcc-systems/Visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/hpcc-systems/Visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'http://rawgit.com/hpcc-systems/Visualization/master/demos/dermatology.html',
#   'hooks_url': 'https://api.github.com/repos/hpcc-systems/Visualization/hooks',
#   'html_url': 'https://github.com/hpcc-systems/Visualization',
#   'id': 22117259,
#   'issue_comment_url': 'https://api.github.com/repos/hpcc-systems/Visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/hpcc-systems/Visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/hpcc-systems/Visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/hpcc-systems/Visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/hpcc-systems/Visualization/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/hpcc-systems/Visualization/languages',
#   'license': {'key': 'other', 'name': 'Other', 'spdx_id': None, 'url': None},
#   'merges_url': 'https://api.github.com/repos/hpcc-systems/Visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/hpcc-systems/Visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Visualization',
#   'notifications_url': 'https://api.github.com/repos/hpcc-systems/Visualization/notifications{?since,all,participating}',
#   'open_issues': 135,
#   'open_issues_count': 135,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/900867?v=4',
#    'events_url': 'https://api.github.com/users/hpcc-systems/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/hpcc-systems/followers',
#    'following_url': 'https://api.github.com/users/hpcc-systems/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hpcc-systems/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/hpcc-systems',
#    'id': 900867,
#    'login': 'hpcc-systems',
#    'organizations_url': 'https://api.github.com/users/hpcc-systems/orgs',
#    'received_events_url': 'https://api.github.com/users/hpcc-systems/received_events',
#    'repos_url': 'https://api.github.com/users/hpcc-systems/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/hpcc-systems/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hpcc-systems/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/hpcc-systems'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/hpcc-systems/Visualization/pulls{/number}',
#   'pushed_at': '2018-05-01T11:46:49Z',
#   'releases_url': 'https://api.github.com/repos/hpcc-systems/Visualization/releases{/id}',
#   'score': 76.915344,
#   'size': 28276,
#   'ssh_url': 'git@github.com:hpcc-systems/Visualization.git',
#   'stargazers_count': 32,
#   'stargazers_url': 'https://api.github.com/repos/hpcc-systems/Visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/hpcc-systems/Visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/hpcc-systems/Visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/hpcc-systems/Visualization/subscription',
#   'svn_url': 'https://github.com/hpcc-systems/Visualization',
#   'tags_url': 'https://api.github.com/repos/hpcc-systems/Visualization/tags',
#   'teams_url': 'https://api.github.com/repos/hpcc-systems/Visualization/teams',
#   'trees_url': 'https://api.github.com/repos/hpcc-systems/Visualization/git/trees{/sha}',
#   'updated_at': '2018-04-13T11:24:12Z',
#   'url': 'https://api.github.com/repos/hpcc-systems/Visualization',
#   'watchers': 32,
#   'watchers_count': 32},
#  {'archive_url': 'https://api.github.com/repos/discreteoptimization/visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/discreteoptimization/visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/discreteoptimization/visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/discreteoptimization/visualization/branches{/branch}',
#   'clone_url': 'https://github.com/discreteoptimization/visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/discreteoptimization/visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/discreteoptimization/visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/discreteoptimization/visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/discreteoptimization/visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/discreteoptimization/visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/discreteoptimization/visualization/contributors',
#   'created_at': '2014-03-22T03:51:49Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/discreteoptimization/visualization/deployments',
#   'description': 'web based visualizations of discrete optimization assignments',
#   'downloads_url': 'https://api.github.com/repos/discreteoptimization/visualization/downloads',
#   'events_url': 'https://api.github.com/repos/discreteoptimization/visualization/events',
#   'fork': False,
#   'forks': 19,
#   'forks_count': 19,
#   'forks_url': 'https://api.github.com/repos/discreteoptimization/visualization/forks',
#   'full_name': 'discreteoptimization/visualization',
#   'git_commits_url': 'https://api.github.com/repos/discreteoptimization/visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/discreteoptimization/visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/discreteoptimization/visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/discreteoptimization/visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'https://discreteoptimization.github.io/vis',
#   'hooks_url': 'https://api.github.com/repos/discreteoptimization/visualization/hooks',
#   'html_url': 'https://github.com/discreteoptimization/visualization',
#   'id': 18001556,
#   'issue_comment_url': 'https://api.github.com/repos/discreteoptimization/visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/discreteoptimization/visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/discreteoptimization/visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/discreteoptimization/visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/discreteoptimization/visualization/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/discreteoptimization/visualization/languages',
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/discreteoptimization/visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/discreteoptimization/visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'visualization',
#   'notifications_url': 'https://api.github.com/repos/discreteoptimization/visualization/notifications{?since,all,participating}',
#   'open_issues': 2,
#   'open_issues_count': 2,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/5465975?v=4',
#    'events_url': 'https://api.github.com/users/discreteoptimization/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/discreteoptimization/followers',
#    'following_url': 'https://api.github.com/users/discreteoptimization/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/discreteoptimization/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/discreteoptimization',
#    'id': 5465975,
#    'login': 'discreteoptimization',
#    'organizations_url': 'https://api.github.com/users/discreteoptimization/orgs',
#    'received_events_url': 'https://api.github.com/users/discreteoptimization/received_events',
#    'repos_url': 'https://api.github.com/users/discreteoptimization/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/discreteoptimization/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/discreteoptimization/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/discreteoptimization'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/discreteoptimization/visualization/pulls{/number}',
#   'pushed_at': '2017-05-11T14:45:34Z',
#   'releases_url': 'https://api.github.com/repos/discreteoptimization/visualization/releases{/id}',
#   'score': 65.27893,
#   'size': 55,
#   'ssh_url': 'git@github.com:discreteoptimization/visualization.git',
#   'stargazers_count': 22,
#   'stargazers_url': 'https://api.github.com/repos/discreteoptimization/visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/discreteoptimization/visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/discreteoptimization/visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/discreteoptimization/visualization/subscription',
#   'svn_url': 'https://github.com/discreteoptimization/visualization',
#   'tags_url': 'https://api.github.com/repos/discreteoptimization/visualization/tags',
#   'teams_url': 'https://api.github.com/repos/discreteoptimization/visualization/teams',
#   'trees_url': 'https://api.github.com/repos/discreteoptimization/visualization/git/trees{/sha}',
#   'updated_at': '2018-04-26T22:15:10Z',
#   'url': 'https://api.github.com/repos/discreteoptimization/visualization',
#   'watchers': 22,
#   'watchers_count': 22},
#  {'archive_url': 'https://api.github.com/repos/dsidavis/Visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/dsidavis/Visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/dsidavis/Visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/dsidavis/Visualization/branches{/branch}',
#   'clone_url': 'https://github.com/dsidavis/Visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/dsidavis/Visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/dsidavis/Visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/dsidavis/Visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/dsidavis/Visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/dsidavis/Visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/dsidavis/Visualization/contributors',
#   'created_at': '2015-04-25T12:42:02Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/dsidavis/Visualization/deployments',
#   'description': 'Material from NSF Workshop on Visualization 25th April 2015',
#   'downloads_url': 'https://api.github.com/repos/dsidavis/Visualization/downloads',
#   'events_url': 'https://api.github.com/repos/dsidavis/Visualization/events',
#   'fork': False,
#   'forks': 15,
#   'forks_count': 15,
#   'forks_url': 'https://api.github.com/repos/dsidavis/Visualization/forks',
#   'full_name': 'dsidavis/Visualization',
#   'git_commits_url': 'https://api.github.com/repos/dsidavis/Visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dsidavis/Visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dsidavis/Visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/dsidavis/Visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/dsidavis/Visualization/hooks',
#   'html_url': 'https://github.com/dsidavis/Visualization',
#   'id': 34568071,
#   'issue_comment_url': 'https://api.github.com/repos/dsidavis/Visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/dsidavis/Visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/dsidavis/Visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/dsidavis/Visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/dsidavis/Visualization/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/dsidavis/Visualization/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/dsidavis/Visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/dsidavis/Visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Visualization',
#   'notifications_url': 'https://api.github.com/repos/dsidavis/Visualization/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/12111698?v=4',
#    'events_url': 'https://api.github.com/users/dsidavis/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/dsidavis/followers',
#    'following_url': 'https://api.github.com/users/dsidavis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dsidavis/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/dsidavis',
#    'id': 12111698,
#    'login': 'dsidavis',
#    'organizations_url': 'https://api.github.com/users/dsidavis/orgs',
#    'received_events_url': 'https://api.github.com/users/dsidavis/received_events',
#    'repos_url': 'https://api.github.com/users/dsidavis/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/dsidavis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dsidavis/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/dsidavis'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/dsidavis/Visualization/pulls{/number}',
#   'pushed_at': '2015-08-25T23:54:38Z',
#   'releases_url': 'https://api.github.com/repos/dsidavis/Visualization/releases{/id}',
#   'score': 60.994965,
#   'size': 23866,
#   'ssh_url': 'git@github.com:dsidavis/Visualization.git',
#   'stargazers_count': 18,
#   'stargazers_url': 'https://api.github.com/repos/dsidavis/Visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/dsidavis/Visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/dsidavis/Visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dsidavis/Visualization/subscription',
#   'svn_url': 'https://github.com/dsidavis/Visualization',
#   'tags_url': 'https://api.github.com/repos/dsidavis/Visualization/tags',
#   'teams_url': 'https://api.github.com/repos/dsidavis/Visualization/teams',
#   'trees_url': 'https://api.github.com/repos/dsidavis/Visualization/git/trees{/sha}',
#   'updated_at': '2017-10-03T21:08:07Z',
#   'url': 'https://api.github.com/repos/dsidavis/Visualization',
#   'watchers': 18,
#   'watchers_count': 18},
#  {'archive_url': 'https://api.github.com/repos/Ovilia/lipstick/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Ovilia/lipstick/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Ovilia/lipstick/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Ovilia/lipstick/branches{/branch}',
#   'clone_url': 'https://github.com/Ovilia/lipstick.git',
#   'collaborators_url': 'https://api.github.com/repos/Ovilia/lipstick/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Ovilia/lipstick/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Ovilia/lipstick/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Ovilia/lipstick/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Ovilia/lipstick/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Ovilia/lipstick/contributors',
#   'created_at': '2018-03-07T09:53:06Z',
#   'default_branch': 'gh-pages',
#   'deployments_url': 'https://api.github.com/repos/Ovilia/lipstick/deployments',
#   'description': '口红颜色可视化 - 为什么你的女神总缺一支口红',
#   'downloads_url': 'https://api.github.com/repos/Ovilia/lipstick/downloads',
#   'events_url': 'https://api.github.com/repos/Ovilia/lipstick/events',
#   'fork': False,
#   'forks': 51,
#   'forks_count': 51,
#   'forks_url': 'https://api.github.com/repos/Ovilia/lipstick/forks',
#   'full_name': 'Ovilia/lipstick',
#   'git_commits_url': 'https://api.github.com/repos/Ovilia/lipstick/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Ovilia/lipstick/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Ovilia/lipstick/git/tags{/sha}',
#   'git_url': 'git://github.com/Ovilia/lipstick.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'http://zhangwenli.com/lipstick/',
#   'hooks_url': 'https://api.github.com/repos/Ovilia/lipstick/hooks',
#   'html_url': 'https://github.com/Ovilia/lipstick',
#   'id': 124214994,
#   'issue_comment_url': 'https://api.github.com/repos/Ovilia/lipstick/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Ovilia/lipstick/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Ovilia/lipstick/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Ovilia/lipstick/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Ovilia/lipstick/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/Ovilia/lipstick/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Ovilia/lipstick/merges',
#   'milestones_url': 'https://api.github.com/repos/Ovilia/lipstick/milestones{/number}',
#   'mirror_url': None,
#   'name': 'lipstick',
#   'notifications_url': 'https://api.github.com/repos/Ovilia/lipstick/notifications{?since,all,participating}',
#   'open_issues': 6,
#   'open_issues_count': 6,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/779050?v=4',
#    'events_url': 'https://api.github.com/users/Ovilia/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Ovilia/followers',
#    'following_url': 'https://api.github.com/users/Ovilia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Ovilia/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Ovilia',
#    'id': 779050,
#    'login': 'Ovilia',
#    'organizations_url': 'https://api.github.com/users/Ovilia/orgs',
#    'received_events_url': 'https://api.github.com/users/Ovilia/received_events',
#    'repos_url': 'https://api.github.com/users/Ovilia/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Ovilia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Ovilia/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Ovilia'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Ovilia/lipstick/pulls{/number}',
#   'pushed_at': '2018-03-08T04:39:37Z',
#   'releases_url': 'https://api.github.com/repos/Ovilia/lipstick/releases{/id}',
#   'score': 56.474648,
#   'size': 907,
#   'ssh_url': 'git@github.com:Ovilia/lipstick.git',
#   'stargazers_count': 591,
#   'stargazers_url': 'https://api.github.com/repos/Ovilia/lipstick/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Ovilia/lipstick/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Ovilia/lipstick/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Ovilia/lipstick/subscription',
#   'svn_url': 'https://github.com/Ovilia/lipstick',
#   'tags_url': 'https://api.github.com/repos/Ovilia/lipstick/tags',
#   'teams_url': 'https://api.github.com/repos/Ovilia/lipstick/teams',
#   'trees_url': 'https://api.github.com/repos/Ovilia/lipstick/git/trees{/sha}',
#   'updated_at': '2018-05-03T13:55:42Z',
#   'url': 'https://api.github.com/repos/Ovilia/lipstick',
#   'watchers': 591,
#   'watchers_count': 591},
#  {'archive_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/branches{/branch}',
#   'clone_url': 'https://github.com/Anti-Gerrymandering/visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/contributors',
#   'created_at': '2017-03-26T22:46:52Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/deployments',
#   'description': "Helping to demonstrate gerrymandering's effect in local counties ",
#   'downloads_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/downloads',
#   'events_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/events',
#   'fork': False,
#   'forks': 11,
#   'forks_count': 11,
#   'forks_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/forks',
#   'full_name': 'Anti-Gerrymandering/visualization',
#   'git_commits_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/Anti-Gerrymandering/visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/hooks',
#   'html_url': 'https://github.com/Anti-Gerrymandering/visualization',
#   'id': 86270215,
#   'issue_comment_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/languages',
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'visualization',
#   'notifications_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/notifications{?since,all,participating}',
#   'open_issues': 8,
#   'open_issues_count': 8,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/26679644?v=4',
#    'events_url': 'https://api.github.com/users/Anti-Gerrymandering/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Anti-Gerrymandering/followers',
#    'following_url': 'https://api.github.com/users/Anti-Gerrymandering/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Anti-Gerrymandering/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Anti-Gerrymandering',
#    'id': 26679644,
#    'login': 'Anti-Gerrymandering',
#    'organizations_url': 'https://api.github.com/users/Anti-Gerrymandering/orgs',
#    'received_events_url': 'https://api.github.com/users/Anti-Gerrymandering/received_events',
#    'repos_url': 'https://api.github.com/users/Anti-Gerrymandering/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Anti-Gerrymandering/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Anti-Gerrymandering/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/Anti-Gerrymandering'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/pulls{/number}',
#   'pushed_at': '2017-10-03T17:03:50Z',
#   'releases_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/releases{/id}',
#   'score': 50.258743,
#   'size': 14655,
#   'ssh_url': 'git@github.com:Anti-Gerrymandering/visualization.git',
#   'stargazers_count': 5,
#   'stargazers_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/subscription',
#   'svn_url': 'https://github.com/Anti-Gerrymandering/visualization',
#   'tags_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/tags',
#   'teams_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/teams',
#   'trees_url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization/git/trees{/sha}',
#   'updated_at': '2017-12-05T01:02:28Z',
#   'url': 'https://api.github.com/repos/Anti-Gerrymandering/visualization',
#   'watchers': 5,
#   'watchers_count': 5},
#  {'archive_url': 'https://api.github.com/repos/LinDA-tools/Visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/LinDA-tools/Visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/LinDA-tools/Visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/LinDA-tools/Visualization/branches{/branch}',
#   'clone_url': 'https://github.com/LinDA-tools/Visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/LinDA-tools/Visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/LinDA-tools/Visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/LinDA-tools/Visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/LinDA-tools/Visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/LinDA-tools/Visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/LinDA-tools/Visualization/contributors',
#   'created_at': '2014-02-02T16:56:03Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/LinDA-tools/Visualization/deployments',
#   'description': None,
#   'downloads_url': 'https://api.github.com/repos/LinDA-tools/Visualization/downloads',
#   'events_url': 'https://api.github.com/repos/LinDA-tools/Visualization/events',
#   'fork': False,
#   'forks': 9,
#   'forks_count': 9,
#   'forks_url': 'https://api.github.com/repos/LinDA-tools/Visualization/forks',
#   'full_name': 'LinDA-tools/Visualization',
#   'git_commits_url': 'https://api.github.com/repos/LinDA-tools/Visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/LinDA-tools/Visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/LinDA-tools/Visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/LinDA-tools/Visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/LinDA-tools/Visualization/hooks',
#   'html_url': 'https://github.com/LinDA-tools/Visualization',
#   'id': 16458458,
#   'issue_comment_url': 'https://api.github.com/repos/LinDA-tools/Visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/LinDA-tools/Visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/LinDA-tools/Visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/LinDA-tools/Visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/LinDA-tools/Visualization/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/LinDA-tools/Visualization/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/LinDA-tools/Visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/LinDA-tools/Visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Visualization',
#   'notifications_url': 'https://api.github.com/repos/LinDA-tools/Visualization/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/6185248?v=4',
#    'events_url': 'https://api.github.com/users/LinDA-tools/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/LinDA-tools/followers',
#    'following_url': 'https://api.github.com/users/LinDA-tools/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LinDA-tools/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/LinDA-tools',
#    'id': 6185248,
#    'login': 'LinDA-tools',
#    'organizations_url': 'https://api.github.com/users/LinDA-tools/orgs',
#    'received_events_url': 'https://api.github.com/users/LinDA-tools/received_events',
#    'repos_url': 'https://api.github.com/users/LinDA-tools/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/LinDA-tools/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LinDA-tools/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/LinDA-tools'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/LinDA-tools/Visualization/pulls{/number}',
#   'pushed_at': '2015-06-05T16:18:31Z',
#   'releases_url': 'https://api.github.com/repos/LinDA-tools/Visualization/releases{/id}',
#   'score': 50.20385,
#   'size': 15282,
#   'ssh_url': 'git@github.com:LinDA-tools/Visualization.git',
#   'stargazers_count': 8,
#   'stargazers_url': 'https://api.github.com/repos/LinDA-tools/Visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/LinDA-tools/Visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/LinDA-tools/Visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/LinDA-tools/Visualization/subscription',
#   'svn_url': 'https://github.com/LinDA-tools/Visualization',
#   'tags_url': 'https://api.github.com/repos/LinDA-tools/Visualization/tags',
#   'teams_url': 'https://api.github.com/repos/LinDA-tools/Visualization/teams',
#   'trees_url': 'https://api.github.com/repos/LinDA-tools/Visualization/git/trees{/sha}',
#   'updated_at': '2015-07-10T10:15:19Z',
#   'url': 'https://api.github.com/repos/LinDA-tools/Visualization',
#   'watchers': 8,
#   'watchers_count': 8},
#  {'archive_url': 'https://api.github.com/repos/dc-js/dc.js/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/dc-js/dc.js/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/dc-js/dc.js/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/dc-js/dc.js/branches{/branch}',
#   'clone_url': 'https://github.com/dc-js/dc.js.git',
#   'collaborators_url': 'https://api.github.com/repos/dc-js/dc.js/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/dc-js/dc.js/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/dc-js/dc.js/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/dc-js/dc.js/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/dc-js/dc.js/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/dc-js/dc.js/contributors',
#   'created_at': '2012-06-19T14:20:30Z',
#   'default_branch': 'develop',
#   'deployments_url': 'https://api.github.com/repos/dc-js/dc.js/deployments',
#   'description': 'Multi-Dimensional charting built to work natively with crossfilter rendered with d3.js',
#   'downloads_url': 'https://api.github.com/repos/dc-js/dc.js/downloads',
#   'events_url': 'https://api.github.com/repos/dc-js/dc.js/events',
#   'fork': False,
#   'forks': 1663,
#   'forks_count': 1663,
#   'forks_url': 'https://api.github.com/repos/dc-js/dc.js/forks',
#   'full_name': 'dc-js/dc.js',
#   'git_commits_url': 'https://api.github.com/repos/dc-js/dc.js/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dc-js/dc.js/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dc-js/dc.js/git/tags{/sha}',
#   'git_url': 'git://github.com/dc-js/dc.js.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/dc-js/dc.js/hooks',
#   'html_url': 'https://github.com/dc-js/dc.js',
#   'id': 4714614,
#   'issue_comment_url': 'https://api.github.com/repos/dc-js/dc.js/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/dc-js/dc.js/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/dc-js/dc.js/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/dc-js/dc.js/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/dc-js/dc.js/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/dc-js/dc.js/languages',
#   'license': {'key': 'other', 'name': 'Other', 'spdx_id': None, 'url': None},
#   'merges_url': 'https://api.github.com/repos/dc-js/dc.js/merges',
#   'milestones_url': 'https://api.github.com/repos/dc-js/dc.js/milestones{/number}',
#   'mirror_url': None,
#   'name': 'dc.js',
#   'notifications_url': 'https://api.github.com/repos/dc-js/dc.js/notifications{?since,all,participating}',
#   'open_issues': 350,
#   'open_issues_count': 350,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/6378965?v=4',
#    'events_url': 'https://api.github.com/users/dc-js/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/dc-js/followers',
#    'following_url': 'https://api.github.com/users/dc-js/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dc-js/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/dc-js',
#    'id': 6378965,
#    'login': 'dc-js',
#    'organizations_url': 'https://api.github.com/users/dc-js/orgs',
#    'received_events_url': 'https://api.github.com/users/dc-js/received_events',
#    'repos_url': 'https://api.github.com/users/dc-js/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/dc-js/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dc-js/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/dc-js'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/dc-js/dc.js/pulls{/number}',
#   'pushed_at': '2018-05-01T16:56:01Z',
#   'releases_url': 'https://api.github.com/repos/dc-js/dc.js/releases{/id}',
#   'score': 45.785297,
#   'size': 38102,
#   'ssh_url': 'git@github.com:dc-js/dc.js.git',
#   'stargazers_count': 6177,
#   'stargazers_url': 'https://api.github.com/repos/dc-js/dc.js/stargazers',
#   'statuses_url': 'https://api.github.com/repos/dc-js/dc.js/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/dc-js/dc.js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dc-js/dc.js/subscription',
#   'svn_url': 'https://github.com/dc-js/dc.js',
#   'tags_url': 'https://api.github.com/repos/dc-js/dc.js/tags',
#   'teams_url': 'https://api.github.com/repos/dc-js/dc.js/teams',
#   'trees_url': 'https://api.github.com/repos/dc-js/dc.js/git/trees{/sha}',
#   'updated_at': '2018-05-03T23:06:22Z',
#   'url': 'https://api.github.com/repos/dc-js/dc.js',
#   'watchers': 6177,
#   'watchers_count': 6177},
#  {'archive_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/branches{/branch}',
#   'clone_url': 'https://github.com/PaddlePaddle/VisualDL.git',
#   'collaborators_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/contributors',
#   'created_at': '2017-12-20T12:34:31Z',
#   'default_branch': 'develop',
#   'deployments_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/deployments',
#   'description': 'A platform to visualize the deep learning process.',
#   'downloads_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/downloads',
#   'events_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/events',
#   'fork': False,
#   'forks': 237,
#   'forks_count': 237,
#   'forks_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/forks',
#   'full_name': 'PaddlePaddle/VisualDL',
#   'git_commits_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/git/tags{/sha}',
#   'git_url': 'git://github.com/PaddlePaddle/VisualDL.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'http://visualdl.paddlepaddle.org',
#   'hooks_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/hooks',
#   'html_url': 'https://github.com/PaddlePaddle/VisualDL',
#   'id': 114885555,
#   'issue_comment_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/languages',
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/merges',
#   'milestones_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/milestones{/number}',
#   'mirror_url': None,
#   'name': 'VisualDL',
#   'notifications_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/notifications{?since,all,participating}',
#   'open_issues': 59,
#   'open_issues_count': 59,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/23534030?v=4',
#    'events_url': 'https://api.github.com/users/PaddlePaddle/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/PaddlePaddle/followers',
#    'following_url': 'https://api.github.com/users/PaddlePaddle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PaddlePaddle/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/PaddlePaddle',
#    'id': 23534030,
#    'login': 'PaddlePaddle',
#    'organizations_url': 'https://api.github.com/users/PaddlePaddle/orgs',
#    'received_events_url': 'https://api.github.com/users/PaddlePaddle/received_events',
#    'repos_url': 'https://api.github.com/users/PaddlePaddle/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/PaddlePaddle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PaddlePaddle/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/PaddlePaddle'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/pulls{/number}',
#   'pushed_at': '2018-05-02T06:47:57Z',
#   'releases_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/releases{/id}',
#   'score': 45.245857,
#   'size': 3462,
#   'ssh_url': 'git@github.com:PaddlePaddle/VisualDL.git',
#   'stargazers_count': 1521,
#   'stargazers_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/stargazers',
#   'statuses_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/subscribers',
#   'subscription_url': 'https://api.github.com/repos/PaddlePaddle/VisualDL/subscription',
#   'svn_url': 'https://github.com/PaddlePaddle/VisualDL',
# ...
#   'collaborators_url': 'https://api.github.com/repos/uber/deck.gl/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/uber/deck.gl/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/uber/deck.gl/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/uber/deck.gl/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/uber/deck.gl/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/uber/deck.gl/contributors',
#   'created_at': '2015-12-15T08:38:29Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/uber/deck.gl/deployments',
#   'description': 'WebGL2 powered geospatial visualization layers',
#   'downloads_url': 'https://api.github.com/repos/uber/deck.gl/downloads',
#   'events_url': 'https://api.github.com/repos/uber/deck.gl/events',
#   'fork': False,
#   'forks': 587,
#   'forks_count': 587,
#   'forks_url': 'https://api.github.com/repos/uber/deck.gl/forks',
#   'full_name': 'uber/deck.gl',
#   'git_commits_url': 'https://api.github.com/repos/uber/deck.gl/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/uber/deck.gl/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/uber/deck.gl/git/tags{/sha}',
#   'git_url': 'git://github.com/uber/deck.gl.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'http://uber.github.io/deck.gl',
#   'hooks_url': 'https://api.github.com/repos/uber/deck.gl/hooks',
#   'html_url': 'https://github.com/uber/deck.gl',
#   'id': 48030204,
#   'issue_comment_url': 'https://api.github.com/repos/uber/deck.gl/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/uber/deck.gl/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/uber/deck.gl/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/uber/deck.gl/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/uber/deck.gl/labels{/name}',
#   'language': 'JavaScript',
#   'languages_url': 'https://api.github.com/repos/uber/deck.gl/languages',
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/uber/deck.gl/merges',
#   'milestones_url': 'https://api.github.com/repos/uber/deck.gl/milestones{/number}',
#   'mirror_url': None,
#   'name': 'deck.gl',
#   'notifications_url': 'https://api.github.com/repos/uber/deck.gl/notifications{?since,all,participating}',
#   'open_issues': 87,
#   'open_issues_count': 87,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/538264?v=4',
#    'events_url': 'https://api.github.com/users/uber/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/uber/followers',
#    'following_url': 'https://api.github.com/users/uber/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/uber/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/uber',
#    'id': 538264,
#    'login': 'uber',
#    'organizations_url': 'https://api.github.com/users/uber/orgs',
#    'received_events_url': 'https://api.github.com/users/uber/received_events',
#    'repos_url': 'https://api.github.com/users/uber/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/uber/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/uber/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/uber'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/uber/deck.gl/pulls{/number}',
#   'pushed_at': '2018-05-03T18:19:20Z',
#   'releases_url': 'https://api.github.com/repos/uber/deck.gl/releases{/id}',
#   'score': 35.60741,
#   'size': 115374,
#   'ssh_url': 'git@github.com:uber/deck.gl.git',
#   'stargazers_count': 4365,
#   'stargazers_url': 'https://api.github.com/repos/uber/deck.gl/stargazers',
#   'statuses_url': 'https://api.github.com/repos/uber/deck.gl/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/uber/deck.gl/subscribers',
#   'subscription_url': 'https://api.github.com/repos/uber/deck.gl/subscription',
#   'svn_url': 'https://github.com/uber/deck.gl',
#   'tags_url': 'https://api.github.com/repos/uber/deck.gl/tags',
#   'teams_url': 'https://api.github.com/repos/uber/deck.gl/teams',
#   'trees_url': 'https://api.github.com/repos/uber/deck.gl/git/trees{/sha}',
#   'updated_at': '2018-05-03T12:58:19Z',
#   'url': 'https://api.github.com/repos/uber/deck.gl',
#   'watchers': 4365,
#   'watchers_count': 4365},
#  {'archive_url': 'https://api.github.com/repos/geohackweek/visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/geohackweek/visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/geohackweek/visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/geohackweek/visualization/branches{/branch}',
#   'clone_url': 'https://github.com/geohackweek/visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/geohackweek/visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/geohackweek/visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/geohackweek/visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/geohackweek/visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/geohackweek/visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/geohackweek/visualization/contributors',
#   'created_at': '2016-09-19T21:27:33Z',
#   'default_branch': 'gh-pages',
#   'deployments_url': 'https://api.github.com/repos/geohackweek/visualization/deployments',
#   'description': 'Visualization Tutorial',
#   'downloads_url': 'https://api.github.com/repos/geohackweek/visualization/downloads',
#   'events_url': 'https://api.github.com/repos/geohackweek/visualization/events',
#   'fork': False,
#   'forks': 6,
#   'forks_count': 6,
#   'forks_url': 'https://api.github.com/repos/geohackweek/visualization/forks',
#   'full_name': 'geohackweek/visualization',
#   'git_commits_url': 'https://api.github.com/repos/geohackweek/visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/geohackweek/visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/geohackweek/visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/geohackweek/visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'https://geohackweek.github.io/visualization',
#   'hooks_url': 'https://api.github.com/repos/geohackweek/visualization/hooks',
#   'html_url': 'https://github.com/geohackweek/visualization',
#   'id': 68648198,
#   'issue_comment_url': 'https://api.github.com/repos/geohackweek/visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/geohackweek/visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/geohackweek/visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/geohackweek/visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/geohackweek/visualization/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/geohackweek/visualization/languages',
#   'license': {'key': 'other', 'name': 'Other', 'spdx_id': None, 'url': None},
#   'merges_url': 'https://api.github.com/repos/geohackweek/visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/geohackweek/visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'visualization',
#   'notifications_url': 'https://api.github.com/repos/geohackweek/visualization/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/19787520?v=4',
#    'events_url': 'https://api.github.com/users/geohackweek/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/geohackweek/followers',
#    'following_url': 'https://api.github.com/users/geohackweek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/geohackweek/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/geohackweek',
#    'id': 19787520,
#    'login': 'geohackweek',
#    'organizations_url': 'https://api.github.com/users/geohackweek/orgs',
#    'received_events_url': 'https://api.github.com/users/geohackweek/received_events',
#    'repos_url': 'https://api.github.com/users/geohackweek/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/geohackweek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/geohackweek/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/geohackweek'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/geohackweek/visualization/pulls{/number}',
#   'pushed_at': '2017-09-08T21:35:16Z',
#   'releases_url': 'https://api.github.com/repos/geohackweek/visualization/releases{/id}',
#   'score': 35.53299,
#   'size': 46779,
#   'ssh_url': 'git@github.com:geohackweek/visualization.git',
#   'stargazers_count': 2,
#   'stargazers_url': 'https://api.github.com/repos/geohackweek/visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/geohackweek/visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/geohackweek/visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/geohackweek/visualization/subscription',
#   'svn_url': 'https://github.com/geohackweek/visualization',
#   'tags_url': 'https://api.github.com/repos/geohackweek/visualization/tags',
#   'teams_url': 'https://api.github.com/repos/geohackweek/visualization/teams',
#   'trees_url': 'https://api.github.com/repos/geohackweek/visualization/git/trees{/sha}',
#   'updated_at': '2017-08-24T23:04:17Z',
#   'url': 'https://api.github.com/repos/geohackweek/visualization',
#   'watchers': 2,
#   'watchers_count': 2},
#  {'archive_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/branches{/branch}',
#   'clone_url': 'https://github.com/BerkeleyAutomation/visualization.git',
#   'collaborators_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/contributors',
#   'created_at': '2016-10-26T22:54:31Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/deployments',
#   'description': 'Visualization tools for the autolab ',
#   'downloads_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/downloads',
#   'events_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/events',
#   'fork': False,
#   'forks': 4,
#   'forks_count': 4,
#   'forks_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/forks',
#   'full_name': 'BerkeleyAutomation/visualization',
#   'git_commits_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/git/tags{/sha}',
#   'git_url': 'git://github.com/BerkeleyAutomation/visualization.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/hooks',
#   'html_url': 'https://github.com/BerkeleyAutomation/visualization',
#   'id': 72051257,
#   'issue_comment_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/languages',
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/merges',
#   'milestones_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/milestones{/number}',
#   'mirror_url': None,
#   'name': 'visualization',
#   'notifications_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1627259?v=4',
#    'events_url': 'https://api.github.com/users/BerkeleyAutomation/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/BerkeleyAutomation/followers',
#    'following_url': 'https://api.github.com/users/BerkeleyAutomation/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BerkeleyAutomation/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/BerkeleyAutomation',
#    'id': 1627259,
#    'login': 'BerkeleyAutomation',
#    'organizations_url': 'https://api.github.com/users/BerkeleyAutomation/orgs',
#    'received_events_url': 'https://api.github.com/users/BerkeleyAutomation/received_events',
#    'repos_url': 'https://api.github.com/users/BerkeleyAutomation/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/BerkeleyAutomation/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BerkeleyAutomation/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/BerkeleyAutomation'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/pulls{/number}',
#   'pushed_at': '2018-04-23T19:07:35Z',
#   'releases_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/releases{/id}',
#   'score': 35.14878,
#   'size': 2056,
#   'ssh_url': 'git@github.com:BerkeleyAutomation/visualization.git',
#   'stargazers_count': 3,
#   'stargazers_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/stargazers',
#   'statuses_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/subscribers',
#   'subscription_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/subscription',
#   'svn_url': 'https://github.com/BerkeleyAutomation/visualization',
#   'tags_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/tags',
#   'teams_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/teams',
#   'trees_url': 'https://api.github.com/repos/BerkeleyAutomation/visualization/git/trees{/sha}',
#   'updated_at': '2018-04-23T19:07:36Z',
#   'url': 'https://api.github.com/repos/BerkeleyAutomation/visualization',
#   'watchers': 3,
#   'watchers_count': 3}]

# %% [markdown]
# Print out the "full name" (i.e., the user and repo name) of the top result from your search.

# %% [markdown]
# _Challenge_: Use the GitHub API to get a list of the contributors to the **`python/cpython`** repository (the source code for the Python programming language!) and the number of commits they've made. This will be a really big response with lots of data! Check the schema description to understand how to navigate it.

# %% [markdown]
# Who were the top 10 contributors in terms of total commits (and how many commits did each make)? _Hint:_ use a list comprehension to _map_ and _filter_ the list for the information you care about, then sort it in descending order by commit count, then output the top 10 items.
